# %% [markdown]
# # Ejercicios Pandas

# %%
import pandas as pd

# %% [markdown]
# **2.** Imprimir la  vessión pandas

# %%
pd.__version__
# Out:
# '2.1.4'

# %% [markdown]
# ## Cuestiones básicas DataFrame
#
#
#
# Nota: recordar importar numpy:
# ```python
# import numpy as np
# ```
#
# Considerar el siguiente diccionario y la lista  `labels`:
#
#
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
#
#
# **3.** Crear un  a DataFrame `df` con los datos del diccionario y el índice  `labels`.

# %%
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **4.** Imprimir un resumen del marco creado.

# %%
df.info()

# ...or...

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes
#             age     visits
# count  8.000000  10.000000
# mean   3.437500   1.900000
# std    2.007797   0.875595
# min    0.500000   1.000000
# 25%    2.375000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000

# %% [markdown]
# **5.** Mostrar las 3 primeras filas de `df` de dos formas distintas.

# %%
df.iloc[:3]

# or equivalently

df.head(3)
# Out:
#    animal  age visits  priority
# a     cat  2.5      1      True
# b     cat  3.0      3      True
# c  python  0.5      2     False

# %% [markdown]
# **6.** Seleccionar las columnas 'animal' y 'age' del mardo de datos df .

# %%
df.loc['a':'c', ['animal', 'age']]
# Out:
#    animal  age
# a     cat  2.5
# b     cat  3.0
# c  python  0.5

# %%
df.loc['a':'c', ['animal', 'age']]

# or

df[['animal', 'age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **7.** Seleccionar los datos en las filas `[3, 4, 8]` *y* en las columnas `['animal', 'age']`.

# %%
df.loc[df.index[[3, 4, 8]], ['animal', 'age']]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
df.loc[df.index[[3, 4, 8]], ['animal', 'age']]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **8.** Seleccionar sólo las filas donde el numero de visitas es mayor que 2.

# %%
df.loc[df['visits'] > 2]
# Out:
#   animal  age visits  priority
# b    cat  3.0      3      True
# d    dog  NaN      3      True
# f    cat  1.5      3     False

# %% [markdown]
# **9.** Seleccione las filas donde falta la edad, es decir, es "NaN".

# %%
df.loc[df['age'].isnull()]
# Out:
#   animal  age visits  priority
# d    dog  NaN      3      True
# h    cat  NaN      1      True

# %%
a=df.loc[:,['animal','age']]
a
# Out:
#    animal  age
# a     cat  2.5
# b     cat  3.0
# c  python  0.5
# d     dog  NaN
# e     dog  5.0
# f     cat  1.5
# g  python  4.5
# h     cat  NaN
# i     dog  7.0
# j     dog  3.0

# %%
gatos = df.loc[df.loc[:, 'animal'] == 'cat']
gatos
# Out:
#   animal  age visits  priority
# a    cat  2.5      1      True
# b    cat  3.0      3      True
# f    cat  1.5      3     False
# h    cat  NaN      1      True

# %%
resultado = gatos.loc[gatos.loc[:,'age']<3]
resultado
# Out:
#   animal  age visits  priority
# a    cat  2.5      1      True
# f    cat  1.5      3     False

# %% [markdown]
# **10.** Seleccione las filas donde el animal es un cat *y* age es menor a 3 (años.

# %%
df[(df['animal'] == 'cat') & (df['age'] < 3)] # nos da una lista de booleanos
# Out:
#   animal  age visits  priority
# a    cat  2.5      1      True
# f    cat  1.5      3     False

# %%
df.loc[(df.animal == "cat") & (df.age < 3),
                ['visits', 'priority']]
# Out:
#   visits  priority
# a      1      True
# f      3     False

# %% [markdown]
# **11.** Seleccione las filas donde age esté entre 2 y 4 (inclusive).

# %%
df[df['age'].between(2, 4)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **12.** Cambie la edad en la fila 'f' a 1,5.

# %%
df.loc['f', 'age'] = 1.5

# %% [markdown]
# **13.** Calcule la suma de todas las visitas en `df` (es decir, el número total de visitas).

# %%
df['visits'].sum()
# Out:
# 19

# %% [markdown]
# **14.** Calcule la edad media de cada animal diferente en "df".

# %%
df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **15.** Agregue una nueva fila 'k' a `df` con los valores que elija para cada columna. Luego elimine esa fila para devolver el DataFrame original.

# %%
df.loc['k'] = [5.5, 'dog', 'no', 2]

# and then deleting the new row...

df = df.drop('k')

# %% [markdown]
# **16.** Cuente el número de cada tipo de animal en `df`.

# %%
df['animal'].value_counts()
# Out:
# animal
# cat      4
# dog      4
# snake    2
# Name: count, dtype: int64

# %% [markdown]
# **17.** Ordene `df` primero por los valores en 'edad' en orden *descendente*, luego por el valor en la columna 'visitas' en orden *ascendente* (por lo que la fila `i` debe ser la primera y la fila `d` debe ser ser la última).

# %%
df.sort_values(by=['age', 'visits'], ascending=[False, True])
# Out:
#   animal  age visits priority
# i    dog  7.0      2       no
# e    dog  5.0      2       no
# g  snake  4.5      1       no
# j    dog  3.0      1       no
# b    cat  3.0      3      yes
# a    cat  2.5      1      yes
# f    cat  1.5      3       no
# c  snake  0.5      2       no
# h    cat  NaN      1      yes
# d    dog  NaN      3      yes

# %% [markdown]
# **18.** La columna "prioridad" contiene los valores "tes" y "no". Reemplace esta columna con una columna de valores booleanos: "yes" debe ser "true" y "no" debe ser "Falso".

# %%
df['priority'] = df['priority'].map({'yes': True, 'no': False})

# %% [markdown]
# **19.** En la columna "animal", cambie las entradas "snake" a "ptthón".

# %%
df['animal'] = df['animal'].replace('snake', 'python')
df
# Out:
#    animal  age visits  priority
# a     cat  2.5      1      True
# b     cat  3.0      3      True
# c  python  0.5      2     False
# d     dog  NaN      3      True
# e     dog  5.0      2     False
# f     cat  1.5      3     False
# g  python  4.5      1     False
# h     cat  NaN      1      True
# i     dog  7.0      2     False
# j     dog  3.0      1     False

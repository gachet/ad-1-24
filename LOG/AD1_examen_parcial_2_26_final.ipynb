# %% [markdown]
# <a href="https://colab.research.google.com/github/gachet/ad-1-24/blob/main/LOG/AD1_examen_parcial_2_26_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Examen Parcial 2 Análisis de Datos I.
# ## Ingeniería en Industria Conectada 10 Diciembre 2025
#
# Nombre :

# %% [markdown]
# ## Parte2.- Ejercicios. (6 ptos)

# %% [markdown]
# #### Ejercicio .- Una empresa de coches ha sacado un nuevo modelo al mercado. Queremos saber la probabilidad de que una persona con una cierta edad y un determinado salario pueda comprar ese coche.

# %%
# 0. Importar librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
# 1. Importar datos y ver las primeras 10 lineas
datos = pd.read_csv('https://drive.google.com/uc?id=1Tt2YOz6CVUCqgQ4Ob50PdWG81UyyeQTB')

# %%
# 2. Visualizar las variables independientes (gráfico de puntos con dos colores en base a la variable compra)

# %%
# 3. Formar el conjunto de datos necesario utilizando las Variables Edad y Salario como independientes y Compra como dependiente

# %%
#4.·Estandarizar los datos predictores utilizando "StandardScaler" de la librería   sklearn o bien con el método visto en clase
#utilizar estos datos para construir el modelo de regresión logística

# %%
#4.- Calcular el Coste Inicial (Escribir las funciones necesarias)
#Debería ser  Cost at initialization [0.69314718]

# %%
#5 Obtener el vector gradiente inicial, debería ser
#Gradient at initialization: [[ 0.1425    ]
# [-0.29831974]
# [-0.17353327]]

# %%
#5.- Implementar Gradiente descendente. Utilizar:
#alfa 0.01,
#iteraciones 200000
#Imprimir el valor final de la función de coste?

# %%
#6.- Dibujar la función de coste

# %%
#7.- Imprimir los valores finales del vector "theta"

# %%
#8 Dibujar la recta de decisión (Cuidado: Utilizar los datos estandarizados)

# %%
# 9. Utilizando las funciones de la librería sklearn:
# Imprimir la precisión del Modelo
#Obtener la matriz de confusión

# %%
#10..-Una persona desconocida con 50 años y salario 350000 que probabilidad tiene de comprar el coche ?
#     Una persona desconocida con 30 años y salario 450000 que probabilidad tiene de comprar el coche ?

# %% [markdown]
# #### Ejercicio 2.- Arbol de Decisión tipo de pez

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
# Leer datos
df = pd.read_csv("https://drive.google.com/uc?id=1hZg7PIyK-ce_r0YWTBUyDLFumQRSCmf8")

df.head(5)
# Out:
#      length    weight    type
# 0  8.618381  7.848030    tuna
# 1  2.522046  8.762507    tuna
# 2  2.035690  7.101971    tuna
# 3  6.695008  4.953932  salmon
# 4  9.834069  7.908453    tuna

# %%
# 1.- Mostrar cuantas filas y columnas?

# %%
# 2.- Imprimir los nombres de las columnas

# %%
# 3.- Imprimir la distribución de clases

# %%
# 4.- Obtener los datos X y la variable objetivo y

# %%
# 5.- Obtener los conjuntos de ntrenamiento (77%) y test (33%)
from sklearn.model_selection import train_test_split

# %%
# Veamos que forma tienen

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# 6.- instaciar el modelo de árbol de decición utilizando el criterio de Gini

# %%
# 7.- Imprimir la Precisión con el conjunto de entrenamiento y el de test

# %%
# 8.- Imprimir la Matriz de Confusión

# %%
# 9.- Visualizar el árbol obtenido
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

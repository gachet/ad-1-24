# %% [markdown]
# <a href="https://colab.research.google.com/github/gachet/ad-1-24/blob/main/eda/exa1-25p.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img width="650" height="100" src="data:image/png;base64,..." />

# %% [markdown]
# #Examen Parcial 1 Análisis de datos I 13 Octubre 2025
# Parte 2 Problemas (6 ptos)
# tiempo: 60 minutos
#
# NOMBRE:

# %%
import numpy as np # linear algebra
import pandas as pd # data manipulation and analysis
import matplotlib.pyplot as plt # data visualization
# %matplotlib inline
import seaborn as sns # data visualization

# %%
data = pd.read_csv("https://drive.google.com/uc?id=1wX7CmxGvEbenpSgNQ-Pt507jusYx2J8F")

# %%
data.head(5)
# Out:
#     age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0  27.0      M      172.3      75.24        21.3       80.0     130.0
# 1  25.0      M      165.0      55.80        15.7       77.0     126.0
# 2  31.0      M      179.6      78.00        20.1       92.0     152.0
# 3  32.0      M      174.5      71.10        18.4       76.0     147.0
# 4  28.0      M      173.8      67.70        17.1       70.0     127.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 0       54.9                     18.4            60.0          217.0     C
# 1       36.4                     16.3            53.0          229.0     A
# 2       44.8                     12.0            49.0          181.0     C
# 3       41.4                     15.2            53.0          219.0     B
# 4       43.5                     27.1            45.0          217.0     B

# %% [markdown]
# Calcule la edad media de cada clase diferente en el dataframe.

# %%
data.groupby('class')['age'].mean()
# Out:
# class
# A    35.268220
# B    37.074096
# C    36.699612
# D    38.058226
# Name: age, dtype: float64

# %% [markdown]
# Cual es el número de las  donde age esté entre 25 y 28 (inclusive)

# %%
data[data['age'].between(26, 28)].value_counts()
# Out:
# age   gender  height_cm  weight_kg  body fat_%  diastolic  systolic  gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm  class
# 27.0  F       157.0      49.1       30.7        70.0       86.0      27.7       19.7                     51.0            167.0          A        2
#       M       181.9      82.7       21.6        83.0       123.0     51.4       13.1                     45.0            235.0          C        1
#               181.8      79.4       19.3        89.0       134.0     23.5       14.7                     45.0            211.0          B        1
#               181.6      84.0       15.0        71.0       122.0     40.1       9.2                      44.0            211.0          C        1
#                          83.1       24.9        86.0       137.0     45.2       5.5                      53.0            224.0          C        1
#                                                                                                                                                 ..
# 26.0  M       179.9      82.5       18.4        93.0       133.0     46.4       22.7                     31.0            248.0          D        1
#                          76.4       14.3        78.0       154.0     56.4       20.2                     50.0            235.0          B        1
#                          75.1       16.5        80.0       145.0     47.8       19.3                     56.0            240.0          A        1
#                          71.5       9.7         64.0       135.0     59.6       17.8                     61.0            239.0          A        1
#               180.2      103.4      24.7        70.0       128.0     67.6       16.2                     46.0            219.0          B        1
# Name: count, Length: 1701, dtype: int64

# %% [markdown]
# Obtener el numero de hombres qye sufren hipertensión diastolic >= 100  y systolic > 140.

# %%
data[(data['diastolic'] >= 100) & (data['systolic'] > 140) & (data['gender']=='M') ].count()
# Out:
# age                        39
# gender                     39
# height_cm                  39
# weight_kg                  39
# body fat_%                 39
# diastolic                  39
# systolic                   39
# gripForce                  39
# sit and bend forward_cm    39
# sit-ups counts             39
# broad jump_cm              39
# class                      39
# dtype: int64

# %%
data[(data.diastolic > 100) & (data.systolic > 140)].value_counts()
# Out:
# age   gender  height_cm  weight_kg  body fat_%  diastolic  systolic  gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm  class
# 21.0  M       172.6      82.10      23.10000    101.0      152.0     41.2        11.1                    48.0            215.0          C        1
# 26.0  M       169.8      82.12      37.20000    111.0      167.0     42.3        9.2                     28.0            185.0          D        1
#               174.2      70.30      24.70000    107.0      149.0     36.7        23.1                    39.0            215.0          C        1
# 29.0  M       181.1      70.00      9.40000     103.0      155.0     42.2        15.3                    54.0            237.0          B        1
# 30.0  M       169.4      62.40      13.60000    103.0      154.0     33.5        16.5                    54.0            197.0          B        1
# 31.0  M       168.7      70.60      23.70000    102.0      145.0     52.0        11.3                    42.0            212.0          B        1
# 33.0  M       167.9      78.40      15.59514    103.0      167.0     49.9        29.0                    55.0            202.0          A        1
# 35.0  M       179.9      79.30      10.50000    109.0      158.0     56.3        26.0                    51.0            238.0          A        1
# 37.0  F       155.2      46.40      22.30000    102.0      159.0     24.8        29.1                    42.0            192.0          A        1
#       M       167.7      77.30      27.80000    102.0      146.0     49.1        15.6                    57.0            226.0          A        1
#               170.3      78.60      30.20000    102.0      143.0     38.8       -7.5                     0.0             152.0          D        1
#               171.9      96.60      38.60000    117.0      155.0     39.5        14.4                    18.0            193.0          D        1
#               172.6      78.26      30.70000    120.0      158.0     40.1        6.6                     28.0            199.0          D        1
# 43.0  M       170.7      93.00      31.40000    108.0      169.0     35.7        0.5                     34.0            187.0          D        1
# 45.0  M       171.0      82.00      27.00000    104.0      147.0     42.3        24.5                    38.0            205.0          D        1
# 47.0  M       169.0      78.30      17.30000    112.0      181.0     39.2        37.0                    37.0            197.0          C        1
# 49.0  F       159.6      56.80      28.80000    105.0      141.0     29.0        21.6                    30.0            153.0          A        1
#       M       173.0      84.70      23.60000    110.0      155.0     34.3        12.2                    32.0            180.0          D        1
# 51.0  F       157.0      54.00      31.40000    106.0      158.0     31.4        23.5                    46.0            156.0          A        1
# 54.0  M       168.2      72.50      22.70000    106.0      144.0     43.2        7.7                     30.0            144.0          C        1
# 55.0  M       162.3      65.50      30.70000    118.0      186.0     40.6        11.9                    23.0            162.0          C        1
# 57.0  M       178.1      84.50      22.60000    102.0      193.0     47.8        20.4                    40.0            221.0          B        1
# 58.0  M       161.8      54.76      18.20000    107.0      191.0     30.1        17.8                    33.0            163.0          B        1
# 59.0  M       160.0      55.60      13.20000    112.0      145.0     32.5        22.1                    48.0            175.0          B        1
# 60.0  F       155.8      69.00      38.80000    113.0      178.0     30.0        17.3                    24.0            123.0          D        1
#       M       169.4      77.54      25.40000    126.0      201.0     48.7        14.5                    38.0            194.0          A        1
#               171.6      71.80      17.80000    121.0      160.0     42.9        17.1                    32.0            203.0          A        1
#               175.5      82.20      25.30000    112.0      170.0     35.4       -2.1                     35.0            169.0          D        1
# 61.0  M       171.1      86.22      31.70000    110.0      170.0     40.6        7.8                     30.0            157.0          B        1
# 63.0  F       153.4      47.30      26.00000    101.0      171.0     21.0        11.9                    16.0            111.0          C        1
#       M       166.9      56.30      24.60000    101.0      195.0     35.5        15.8                    23.0            161.0          C        1
#               173.1      70.40      20.90000    109.0      188.0     40.0        16.8                    43.0            192.0          A        1
# 64.0  F       149.0      47.60      29.00000    104.0      176.0     23.4        20.4                    24.0            127.0          B        1
# Name: count, dtype: int64

# %% [markdown]
# 1.-

# %% [markdown]
# ##Análisis Exploratorio

# %% [markdown]
# 1.-  0.6 pto
# a) Eliminar la columna gender en el dataframe original
# b) imprimir  la edad mínima
# c)imprimir la edad máxima
# d) imprimir la media de cada columa?

# %% [markdown]
# 2   0.6 pto
# a) Cúantos *elementos* de clase tipo A existen ?
# b)Cúal es el peso mas frecuente?
# c)Cúal es la estatura mas frecuente ?
# d)Cúal es el porcentaje de grasa en el cuerpo mas frecuente ?

# %% [markdown]
# 3.-   0.6 pto
# a) Existen valores nulos en el conjunto ? y si los hay cuántos son
# b) Existen duplicados?
# c) Eliminar tanto los nulos y los duplicados si es el caso

# %% [markdown]
# 4,.   0.6 pto
# a) Realizar un histograma de la variable peso
# b) Realizar un historama de la variable estatura
# c) Existe una distribución normal para cada variable?
# d) Existe sesgo en alguna de estas dos variables ?

# %% [markdown]
# 5.-  0.6 pto
# a) Hacer un diagrama de cajas para la variable tensión sistólica
# b) Hacer un diagrama de cajas para la variable tensión diastólica
# c) Existen valores superiores atípicos en ambos casos y a partir de que valor?
# d) Cuál es el IQR para la variable presión diastólica?

# %% [markdown]
# 6.-  0.6 pto
# a) Queremos un gráfico de barras para la variable sit-ups count
# b) Hacer un gráfico para ver si las variables peso y grasa corporal están   relacionadas
# c) lo mismo para estatura y presión sistólica

# %% [markdown]
# 7.- 0.6 pto Existe correlación entre  las variables " estatura y presión sistólica" ?
#
# a)Si existe cuál es el valor de esta correlación ?
# b) Que conclusión podemos obtener de esta información ?

# %% [markdown]
# 8.- 0.6  Hagamos un diagrama de cajas para ver la relación entre "Class" y "Sit-up counts"
#
# a) Qué clase de personas hacen mas sentadillas  y cuáles menos ?

# %% [markdown]
# 9.-0.6  lo mismo pero para las variables clase y "grip Force"
#
# a) Qué clase de personas hacen mas fuerza en el agarre  y cuáles menos ?

# %% [markdown]
# 10.-   0.6 pto
# Calcular la matriz de correlación y hacer un mapa de calor para ver las correlaciones
